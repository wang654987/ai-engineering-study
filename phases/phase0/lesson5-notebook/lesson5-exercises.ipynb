# %%
import numpy as np
n = 100_000

# %%
# %timeit [np.random.random() for _ in range(n)]
# Out:
# 17.9 ms ± 345 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit np.random.random(n)
# Out:
# 350 μs ± 4.76 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# #我的分析

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.DataFrame({
"model": ["Linear", "Random Forest", "Neural Net"],
"accuracy": [0.72, 0.89, 0.94],
"training_time": [0.1, 2.3, 45.6]
})
df
# Out:
#            model  accuracy  training_time
# 0         Linear      0.72            0.1
# 1  Random Forest      0.89            2.3
# 2     Neural Net      0.94           45.6

# %%
plt.figure(figsize=(8, 4))
plt.bar(df["model"], df["accuracy"])
plt.title("Model Accuracy Comparison")
plt.ylabel("Accuracy")
plt.show()
